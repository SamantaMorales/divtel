# %%
# !pwd
# Out:
# /Users/macbook/divtel/MST

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
import sys
from ipywidgets import interactive, FloatSlider, interact, fixed
from divtel import *


import copy
import astropy.units as u
from astropy.coordinates import SkyCoord
from astroplan.plots import plot_sky
from astroplan import FixedTarget
#from . import utils
#from .const import COLORS
#from . import pointing

from matplotlib.transforms import Affine2D
from astropy.visualization.wcsaxes import SphericalCircle

import healpy as hp
import tqdm

#!jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# The Idea is to have two notebooks, one for MST configuration confronting just one altitude and the other for them changing with zenith
# This one should be just for

# %% [markdown]
# ## LOAD CTA CONFIG

# %%
cta = CTA_Info('south')
# Out:
# Observer         :  CTA South
# Location         :  Paranal , (1946.635798, -5467.63394562, -2642.49852123) km
# Observation time :  2025-03-08T16:43:48.774

# %%
# Note that if the radius is in meters, 
# you can set LoadConfig(file, radius="meters")
# defalut is in degrees

array = LoadConfig("/Users/macbook/divtel/ParanalArrayPositions_divProd6.txt", frame=cta)
full_array= LoadConfig("/Users/macbook/divtel/Paranal_only_MST.txt", frame=cta)

# %% [markdown]
# ## Check configuration table

# %%
array.table.units = "deg"
array.table
full_array.table
# Out:
# <Table length=14>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1     0.0     0.0    24.0   0.000 ...   1.000  -0.000   0.000   22.65
#     2     0.0   151.0    25.0   0.000 ...   1.000  -0.000   0.000  152.67
#     3     0.0  -151.0    31.0   0.000 ...   1.000  -0.000   0.000  152.68
#     4   150.0    75.0    21.0   0.000 ...   1.000  -0.000   0.000  188.09
#     5   150.0   -75.0    26.0   0.000 ...   1.000  -0.000   0.000  187.98
#     6   150.0   240.0    24.0   0.000 ...   1.000  -0.000   0.000  295.50
#     7   150.0  -240.0    30.0   0.000 ...   1.000  -0.000   0.000  295.49
#     8   313.0     0.0    19.0   0.000 ...   1.000  -0.000   0.000  335.47
#     9  -150.0   -75.0    28.0   0.000 ...   1.000  -0.000   0.000  148.05
#    10  -150.0    75.0    28.0   0.000 ...   1.000  -0.000   0.000  148.05
#    11  -150.0  -240.0    38.5   0.000 ...   1.000  -0.000   0.000  272.05
#    12  -150.0   240.0    27.0   0.000 ...   1.000  -0.000   0.000  271.83
#    13  -313.0  -162.0    35.0   0.000 ...   1.000  -0.000   0.000  332.82
#    14  -313.0   162.0    30.5   0.000 ...   1.000  -0.000   0.000  332.75

# %%
table=array.table

# %% [markdown]
# ## Check the telescope spatial distribution
# This is useful to pick the groups

# %%
array.table
# Out:
# <Table length=64>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      deg   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1   -20.0   -65.0    34.0   0.000 ...   1.000  -0.000   0.000   66.52
#     2    80.0     0.0    29.0   0.000 ...   1.000  -0.000   0.000   86.67
#     3   -20.0    65.0    31.0   0.000 ...   1.000  -0.000   0.000   66.37
#     4  -120.0     0.0    33.0   0.000 ...   1.000  -0.000   0.000  113.39
#     5     0.0     0.0    24.0   0.000 ...   1.000  -0.000   0.000    8.55
#     6     0.0   151.0    25.0   0.000 ...   1.000  -0.000   0.000  151.21
#     7     0.0  -151.0    31.0   0.000 ...   1.000  -0.000   0.000  151.16
#     8   150.0    75.0    21.0   0.000 ...   1.000  -0.000   0.000  173.90
#     9   150.0   -75.0    26.0   0.000 ...   1.000  -0.000   0.000  173.73
#   ...     ...     ...     ...     ... ...     ...     ...     ...     ...
#    56   748.0   367.0    6.25   0.000 ...   1.000  -0.000   0.000  839.50
#    57   816.0  -648.0   41.25   0.000 ...   1.000  -0.000   0.000 1047.30
#    58   816.0   648.0   18.75   0.000 ...   1.000  -0.000   0.000 1047.28
#    59     0.0  -950.0   75.25   0.000 ...   1.000  -0.000   0.000  951.13
#    60     0.0   950.0   28.25   0.000 ...   1.000  -0.000   0.000  950.02
#    61  -955.0  -199.0   39.25   0.000 ...   1.000  -0.000   0.000  969.03
#    62  -955.0   199.0   22.75   0.000 ...   1.000  -0.000   0.000  969.01
#    63   955.0  -199.0    7.75   0.000 ...   1.000  -0.000   0.000  982.28
#    64   955.0   199.0    5.25   0.000 ...   1.000  -0.000   0.000  982.34

# %%
# Loop through all the telescopes
#for fov in array.table["fov"]:
#    print(fov)
colors = [
    'lightseagreen' if np.isclose(fov, 14.5356) else
    'blueviolet' if np.isclose(fov, 46.707) else 
    'green' if np.isclose(fov, 62.462) else
    'red'  # Default color if none of the conditions match
    for fov in array.table["fov"]
]
fov_labels = {
    'lightseagreen': 'LST',
    'blueviolet': 'MST',
    'green': 'SST'
}
for i in range(len(array.table)):
    plt.scatter(array.table['x'][i], array.table['y'][i], c=colors[i], label=fov_labels[colors[i]])

    # Annotate each point with the telescope ID
    #matplotlib.pyplot.annotate(text, xy, xytext=None, xycoords='data', textcoords=None, arrowprops=None, annotation_clip=None, **kwargs)
#Annotate the point xy with text text.
#In the simplest form, the text is placed at xy.
    plt.annotate(str(array.table["id"][i]),
                 (array.table['x'][i], array.table['y'][i]),  # Point position
                 textcoords="offset points",  # Text position relative to the point
                 xytext=(5, 5),  # Offset in pixels (to avoid overlapping the point)
                 ha='center', fontsize=10, color='blue')
handles, labels = plt.gca().get_legend_handles_labels()
#handles, labels like this is doing
    #plt.gca() gets the current Axes object, which is where your plot is
    #.get_legend_handles_labels()
        #handles: Returns a list of the graphical elements (e.g., lines, scatter plot points) that would appear in the legend.
        # labels: Returns the text labels associated with each graphical element in handles

by_label = dict(zip(labels, handles))  # Remove duplicate labels, the dictionary by the structure takes out the double 
plt.legend(by_label.values(), by_label.keys())
#by_label.values This is pulling out the unique graphical elements
# by_label.keys  This is retrieving the unique text 
plt.savefig("./different_telescopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Check the hyper field of view (hFoV)

# %% [markdown]
# This is the whole telescope array hFoV maybe? (ask)

# %%
array.hFoV(m_cut=3)
# Out:
# 64it [00:09,  7.11it/s]
# (62.238869377690584, 57.415086388537716)

# %%
#array.hFoV(m_cut=3)

# %% [markdown]
# ## Grouping telescopes

# %%
sub_groups={'1':[7,8,11], 
            '2': [5,13,16,18],
            '3': [14,15,17], 
            '4': [6,10,12,9]}
second_best={'1':[16,18,13], 
            '2': [14,17,15],
            '3': [5,6,10,9], 
            '4': [7,8,11,12]}

# %%
def compute_center_of_gravity(group):
    x, y, z = group['x'], group['y'], group['z']
    cog_x = round(np.mean(x),2)
    cog_y = round(np.mean(y),2)
    cog_z = round(np.mean(z),2)
    return cog_x, cog_y, cog_z

# Function to create new telescope list with center of gravity
def create_new_group_list(tel_group):
    new_telescopes = []
    for group in tel_group.groups:
        print(tel_group.groups)
        print (group['focal'][0],round(group['radius'][0],2))
        #id_ = group["id"][0]
        cog = compute_center_of_gravity(group)
        focal, fov = group['focal'][0], round(group['radius'][0],2)  # Assuming same within a group
        new_telescopes.append([*cog, focal, fov])
    return new_telescopes

# %%
tel_group_2, labels_2, number_of_telescopes_subarray_2 =array.group_by(second_best)
#tel_group_3, labels_3 = group_by(array, group=only_MST)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 tel_group_2, labels_2, number_of_telescopes_subarray_2 =array.group_by(second_best)
#
# File ~/divtel/divtel/array.py:938, in Array.group_by(self, group)
#     936     number_of_telescopes_subarray.append(index_of_sub_telescope)
#     937     for i in group[key]:
# --> 938         groupping[i-1] = j
#     939     j+=1
#     940 tel_group = self._table.group_by(np.asarray(groupping))
#
# IndexError: index 15 is out of bounds for axis 0 with size 4

# %%
tel_group, labels, number_of_telescopes_subarray_1 =array.group_by(sub_groups)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 tel_group, labels, number_of_telescopes_subarray_1 =array.group_by(sub_groups)
#
# File ~/divtel/divtel/array.py:938, in Array.group_by(self, group)
#     936     number_of_telescopes_subarray.append(index_of_sub_telescope)
#     937     for i in group[key]:
# --> 938         groupping[i-1] = j
#     939     j+=1
#     940 tel_group = self._table.group_by(np.asarray(groupping))
#
# IndexError: index 6 is out of bounds for axis 0 with size 4

# %%
# Step 2: Create new telescope list with center of gravity
new_telescopes = create_new_group_list(tel_group)
new_telescopes_2 = create_new_group_list(tel_group_2)
# Out:
# <TableGroups indices=[ 0 50 53 57 60 64]>
# 28.0 2.15
# <TableGroups indices=[ 0 50 53 57 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 57 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 57 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 57 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 56 60 64]>
# 28.0 2.15
# <TableGroups indices=[ 0 50 53 56 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 56 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 56 60 64]>
# 16.0 3.85
# <TableGroups indices=[ 0 50 53 56 60 64]>
# 16.0 3.85

# %%
#del new_telescopes[0]# Step 3: Output the result
#for telescope in new_telescopes:
#    print(telescope)
del new_telescopes[0]#No clue why it keeps on putting me an extra telescope...soooo... I deleted it... I will find out why
for telescope in new_telescopes:
    print(telescope)
# Out:
# [100.0, -105.33, 27.33, 16.0, 3.85]
# [-153.25, 81.75, 27.38, 16.0, 3.85]
# [-204.33, -109.0, 33.83, 16.0, 3.85]
# [153.25, 79.0, 23.5, 16.0, 3.85]

# %%
del new_telescopes_2[0]
for telescope in new_telescopes_2:
    print(telescope)
# Out:
# [-204.33, 109.0, 28.5, 16.0, 3.85]
# [-204.33, -109.0, 33.83, 16.0, 3.85]
# [75.0, 79.0, 24.75, 16.0, 3.85]
# [153.25, -79.0, 25.25, 16.0, 3.85]

# %%
# Define the file path where you want to save the output
output_file_path = './subarray_1_2_SOUTH.txt'

# Open the file in write mode
with open(output_file_path, 'w') as file:
    
    # Write a header
    #file.write("Group ID, X_Center, Y_Center, Z_Center, Focal Length, FOV\n")
    
    # Loop through all new telescopes (grouped telescopes)
    for i, telescope in enumerate(new_telescopes):
        # Assuming telescope is a list like [x_center, y_center, z_center, focal_length, fov]
        values = ' '.join(map(str, telescope))  # Convert all elements to string
        # Write the data to the file
        #print(values)
        file.write(f"{values}\n")

print(f"New telescope data has been written to {output_file_path}")
# Out:
# New telescope data has been written to ./subarray_1_2_SOUTH.txt

# %%
range(len(array.telescopes))
# Out:
# range(0, 64)

# %%
# Define the file path where you want to save the output
output_file_path_2 = 'subarray_2_SOUTH.txt'

# Open the file in write mode
with open(output_file_path_2, 'w') as file:
    
    # Write a header
    #file.write("Group ID, X_Center, Y_Center, Z_Center, Focal Length, FOV\n")
    
    # Loop through all new telescopes (grouped telescopes)
    for i, telescope in enumerate(new_telescopes_2):
        # Assuming telescope is a list like [x_center, y_center, z_center, focal_length, fov]
        values = ' '.join(map(str, telescope))  # Convert all elements to string
        # Write the data to the file
        #print(values)
        file.write(f"{values}\n")

print(f"New telescope data has been written to {output_file_path_2}")
# Out:
# New telescope data has been written to subarray_2_SOUTH.txt

# %% [markdown]
# ## SANITY CHECK

# %%
#array_3.table

# %% [markdown]
# # THE FIELD OF VIEW

# %% [markdown]
# ## GRAPHING MULTIPLICITY AND FOV to understand what is going on

# %%
array= LoadConfig("./subarray_1_2_SOUTH.txt", frame=cta, pointing2src=True)
array_2= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)

# %%
array.table
# Out:
# <Table length=4>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1   100.0 -105.33   27.33   0.000 ...   1.000  -0.000   0.000  156.04
#     2 -153.25   81.75   27.38   0.000 ...   1.000  -0.000   0.000  158.82
#     3 -204.33  -109.0   33.83   0.000 ...   1.000  -0.000   0.000  202.35
#     4  153.25    79.0    23.5   0.000 ...   1.000  -0.000   0.000  201.79

# %%
full_array.table
# Out:
# <Table length=14>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      deg   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1     0.0     0.0    24.0  -0.000 ...   0.348   0.000   0.937   22.65
#     2     0.0   151.0    25.0 352.708 ...   0.348   0.044   0.937  152.67
#     3     0.0  -151.0    31.0   7.292 ...   0.347  -0.044   0.937  152.68
#     4   150.0    75.0    21.0 356.773 ...   0.386   0.022   0.922  188.09
#     5   150.0   -75.0    26.0   3.227 ...   0.386  -0.022   0.922  187.98
#     6   150.0   240.0    24.0 349.771 ...   0.385   0.070   0.920  295.50
#     7   150.0  -240.0    30.0  10.229 ...   0.385  -0.069   0.920  295.49
#     8   313.0     0.0    19.0  -0.000 ...   0.426   0.000   0.905  335.47
#     9  -150.0   -75.0    28.0   4.164 ...   0.308  -0.022   0.951  148.05
#    10  -150.0    75.0    28.0 355.836 ...   0.308   0.022   0.951  148.05
#    11  -150.0  -240.0    38.5  13.116 ...   0.306  -0.071   0.949  272.05
#    12  -150.0   240.0    27.0 346.884 ...   0.307   0.072   0.949  271.83
#    13  -313.0  -162.0    35.0  10.583 ...   0.262  -0.049   0.964  332.82
#    14  -313.0   162.0    30.5 349.417 ...   0.262   0.049   0.964  332.75

# %%
array.table
# Out:
# <Table length=4>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1   100.0 -105.33   27.33   0.000 ...   1.000  -0.000   0.000  156.04
#     2 -153.25   81.75   27.38   0.000 ...   1.000  -0.000   0.000  158.82
#     3 -204.33  -109.0   33.83   0.000 ...   1.000  -0.000   0.000  202.35
#     4  153.25    79.0    23.5   0.000 ...   1.000  -0.000   0.000  201.79

# %%
full_array.divergent_pointing(0.05, az=0,alt=70)
# Out:
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142

# %%
full_array.hFoV(m_cut=3)[0]
# Out:
# 14it [00:01,  7.20it/s]
# 0.4589887122248568

# %%
full_array.hFoV()[0]
# Out:
# 14it [00:01,  7.42it/s]
# 390.2715450231926

# %%
full_array.multiplicity_plot()
# Out:
# 14it [00:01,  7.39it/s]
# 14it [00:01,  7.06it/s]

# %%
div=[0.0022,0.0043, 0.008, 0.01135, 0.01453, 0.01753, 0.02053, 0.02353, 0.02653, 0.02953]

# %%
FoV_full_array=[]
multiplicity_full_array=[]
for divergence in div:
    full_array.divergent_pointing(divergence, az=0,alt=70)
    if full_array.hFoV(m_cut=3)[0] != 0: #To get the no saturation
        FoV=full_array.hFoV(m_cut=3)[0]
        multiplicity=full_array.hFoV(m_cut=3)[1]
        FoV_full_array.append(FoV)
        multiplicity_full_array.append(multiplicity)
# Out:
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.54it/s]
# 14it [00:01,  7.59it/s]
# 14it [00:01,  7.50it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.58it/s]
# 14it [00:01,  7.15it/s]
# 14it [00:01,  7.25it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:02,  6.95it/s]
# 14it [00:01,  7.46it/s]
# 14it [00:01,  7.22it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.39it/s]
# 14it [00:01,  7.63it/s]
# 14it [00:01,  7.58it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.17it/s]
# 14it [00:01,  7.04it/s]
# 14it [00:02,  6.80it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.11it/s]
# 14it [00:02,  6.94it/s]
# 14it [00:01,  7.43it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.43it/s]
# 14it [00:01,  7.46it/s]
# 14it [00:01,  7.23it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.32it/s]
# 14it [00:01,  7.45it/s]
# 14it [00:01,  7.47it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.45it/s]
# 14it [00:01,  7.58it/s]
# 14it [00:01,  7.55it/s]
# The barycenter -22.357142857142858
# The barycenter 0.0
# The barycenter 27.642857142857142
# 14it [00:01,  7.41it/s]
# 14it [00:01,  7.39it/s]
# 14it [00:01,  7.28it/s]

# %%
array.table
# Out:
# <Table length=4>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1   100.0 -105.33   27.33   0.000 ...   1.000  -0.000   0.000  156.04
#     2 -153.25   81.75   27.38   0.000 ...   1.000  -0.000   0.000  158.82
#     3 -204.33  -109.0   33.83   0.000 ...   1.000  -0.000   0.000  202.35
#     4  153.25    79.0    23.5   0.000 ...   1.000  -0.000   0.000  201.79

# %%
FoV_array_complete=[]
multiplicity_array_complete=[]
FoV_array=[]#This will be the one without saturation
multiplicity_array=[] #This will be the one without saturation
for divergence in div:
    array.divergent_pointing(divergence, az=0,alt=70)    
    FoV=array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[0]
    multiplicity=array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[1]
    FoV_array_complete.append(FoV)
    multiplicity_array_complete.append(multiplicity)
# Out:
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.23it/s]
# 4it [00:00,  7.48it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.36it/s]
# 4it [00:00,  7.37it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.40it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.42it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.24it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.19it/s]
# 4it [00:00,  7.26it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.28it/s]
# 4it [00:00,  7.55it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.56it/s]
# 4it [00:00,  7.48it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.39it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.44it/s]

# %%
FoV_array=[]#This will be the one without saturation
multiplicity_array=[] #This will be the one without saturation
div_no_saturation_sub_1=[]
for i in range(np.size(FoV_array_complete)-1):
        if np.round(FoV_array_complete[i+1])!=np.round(FoV_array_complete[i]):
            FoV_array.append(FoV_array_complete[i])
            multiplicity_array.append(multiplicity_array_complete[i])
print(np.size(FoV_array))
div_stop=np.size(FoV_array)
div_no_saturation_sub_1=div[:div_stop] 
print(FoV_array)
# Out:
# 9
# [51.32805198994542, 56.06219270746465, 64.5469269020213, 72.86117957489442, 80.87381109401977, 88.5979354226038, 96.54499712569702, 104.79367998253802, 112.95056509693406]

# %%
div_no_saturation_sub_1
# Out:
# [0.0022, 0.0043, 0.008, 0.01135, 0.01453, 0.01753, 0.02053, 0.02353, 0.02653]

# %%
array_2.table
# Out:
# <Table length=4>
#   id     x       y       z       az   ...   p_x     p_y     p_z    d_tel
#          m       m       m      rad   ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1 -204.33   109.0    28.5   0.000 ...   1.000  -0.000   0.000  192.96
#     2 -204.33  -109.0   33.83   0.000 ...   1.000  -0.000   0.000  193.05
#     3    75.0    79.0   24.75   0.000 ...   1.000  -0.000   0.000  143.79
#     4  153.25   -79.0   25.25   0.000 ...   1.000  -0.000   0.000  213.52

# %%
FoV_array_complete_2=[]
multiplicity_array_complete_2=[]
FoV_array_2=[]#This will be the one without saturation
multiplicity_array_2=[] #This will be the one without saturation
for divergence in div:
    array_2.divergent_pointing(divergence, az=0,alt=70)    
    FoV=array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[0]
    multiplicity=array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1]
    FoV_array_complete_2.append(FoV)
    multiplicity_array_complete_2.append(multiplicity)
    
FoV_array_2=[]#This will be the one without saturation
multiplicity_array_2=[] #This will be the one without saturation
div_no_saturation_sub_2=[]
# Out:
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.13it/s]
# 4it [00:00,  7.34it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.47it/s]
# 4it [00:00,  7.16it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.38it/s]
# 4it [00:00,  6.64it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.30it/s]
# 4it [00:00,  7.50it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.49it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.47it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.43it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.37it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.42it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.44it/s]

# %%
for i in range(np.size(FoV_array_complete_2)-1):
        if np.round(FoV_array_complete_2[i+1])!=np.round(FoV_array_complete_2[i]):
            FoV_array_2.append(FoV_array_complete_2[i])
            multiplicity_array_2.append(multiplicity_array_complete_2[i])
print(np.size(FoV_array_2))
div_stop_2=np.size(FoV_array_2)
div_no_saturation_sub_2=div[:div_stop_2] 
print(FoV_array_2)
# Out:
# 9
# [51.31493802673899, 56.285130081973875, 65.42556243685173, 73.70047322010558, 81.97538400335944, 89.89621778003982, 98.22358441611937, 106.55095105219891, 115.10125506278767]

# %%
print(len(div), len(FoV_full_array), len(FoV_array))
# Out:
# 10 10 9

# %% [markdown]
# # MULTIPLICITY PLOTS WITH THE RANGES

# %% [raw]
# ##Puting the stop to when we expect the divergence to be too much for us to have cross overs between the different FoV of the single telescopes
# stop=0.036 #From what we saw in the previous slides
# stop_div=[]
# for div in div_no_saturation_sub_1:
#     print(np.round(div,3))
#     #print("stop is:")
#     #print(stop)
#     if np.round(div, 3)  <= stop:
#         print(div)
#         stop_div.append(div)
# array_slice_stop = np.size(stop_div) #This is to slice the array

# %% [raw]
# stop_div

# %% [raw]
# for divergence in stop_div:
#     full_array.divergent_pointing(div=divergence, az=0, alt=70)
#     full_array.multiplicity_plot()

# %% [raw]
# for divergence in stop_div:
#     array.divergent_pointing(div=divergence, az=0, alt=70)
#     array.multiplicity_plot(number_of_telescopes_subarray_1)

# %% [raw]
# for divergence in stop_div:
#     array_2.divergent_pointing(div=divergence, az=0, alt=70)
#     array_2.multiplicity_plot(number_of_telescopes_subarray_2)

# %% [raw]
# for divergence in stop_div:
#     array_3.divergent_pointing(div=divergence, az=0, alt=70)
#     array_3.multiplicity_plot(number_of_telescopes_subarray_3)

# %% [raw]
# for divergence in stop_div:
#     array_4.divergent_pointing(div=divergence, az=0, alt=70)
#     array_4.multiplicity_plot(number_of_telescopes_subarray_4)

# %% [raw]
# ##Puting a different stop to the full the configuration 1 and configuration 2
# stop_sub_1_2_full=0.029 #From what we saw in the previous slides
# stop_div_sub_1_2_full=[]
# for div in div_no_saturation_sub_1:
#     print(div)
#     if np.round(div,3) <= stop_sub_1_2_full:
#         stop_div_sub_1_2_full.append(div)
# array_slice_stop_sub_1_2_full = np.size(stop_div_sub_1_2_full) #This is to slice the array

# %% [raw]
# plt.plot(stop_div_sub_1_2_full, FoV_full_array[:array_slice_stop_sub_1_2_full], label='Full Array m_cut=3', color='darkred')
# plt.plot(stop_div_sub_1_2_full, FoV_array[:array_slice_stop_sub_1_2_full], label='Sub Array 1', color='darkcyan')
# plt.plot(stop_div_sub_1_2_full, FoV_array_2[:array_slice_stop_sub_1_2_full], label='Sub Array 2', color='darkmagenta')
# plt.plot(stop_div, FoV_array_3[:array_slice_stop], label='Sub Array 3',color='limegreen')
# plt.plot(stop_div, FoV_array_4[:array_slice_stop], label='Sub Array 4', color='darkgreen')
# # Add labels and title
# plt.xlabel("Divergence (deg)")
# plt.ylabel("Field of View")
# plt.title("FoV vs Divergence")
#
# # Add legend
# plt.legend()
#
# # Display the plot
# plt.show()
# plt.plot(stop_div_sub_1_2_full, multiplicity_full_array[:array_slice_stop_sub_1_2_full], label='Full Array', color='darkred')
# plt.plot(stop_div_sub_1_2_full,  multiplicity_array[:array_slice_stop_sub_1_2_full], label='Subarray 1', color='darkcyan')
# plt.plot(stop_div_sub_1_2_full,  multiplicity_array_2[:array_slice_stop_sub_1_2_full], label='Subarray 2', color='darkmagenta')
# plt.plot(stop_div,  multiplicity_array_3[:array_slice_stop], label='Subarray 3', color='limegreen')
# plt.plot(stop_div,  multiplicity_array_4[:array_slice_stop], label='Subarray 4', color='darkgreen')
# plt.xlabel("Divergence")
# plt.ylabel("Multiplicity")  # Y-axis label
# plt.title("Multiplicity vs Divergence")  # Title of the plot
# plt.legend()
# plt.show()

# %% [raw]
# fig, axes = plt.subplots(3, 2, figsize=(15, 18))
# # Plot Full Array
# # Full Array with m_cut = 3
# l1=axes[0,0].plot(stop_div_sub_1_2_full, FoV_full_array[:array_slice_stop_sub_1_2_full], label='FoV', marker='o', color='darkgreen')
# ax2 = axes[0,0].twinx()
# l2=ax2.plot(stop_div_sub_1_2_full, multiplicity_full_array[:array_slice_stop_sub_1_2_full], label='Multiplicities',marker='*', color='limegreen')
# axes[0,0].set_title('Full Array m_cut 3')
# axes[0,0].set_xlabel('Divergence')
# axes[0,0].set_ylabel('Field of view (m > 3) [deg$^2$]')
# ax2.set_ylabel('Multiplicities (m>3)')
# axeslegend = l1+l2
# axes[0,0].legend(axeslegend, [l.get_label() for l in axeslegend])
#
#
#
# #Plot the ones for subarray 1
# l1=axes[0,1].plot(stop_div_sub_1_2_full, FoV_array[:array_slice_stop_sub_1_2_full], label='FoV',marker='o', color='darkgreen')
# ax5=axes[0,1].twinx()
# l2=ax5.plot(stop_div_sub_1_2_full, multiplicity_array[:array_slice_stop_sub_1_2_full], label='Multiplicity', marker='*', color='limegreen')
# axes[0,1].set_title('SUBARRAY 1')
# axes[0,1].set_xlabel('Divergence')
# axes[0,1].set_ylabel('Field of view [deg$^2$]')
# ax5.set_ylabel('Multiplicities')
# axeslegend = l1+l2
# axes[0,1].legend(axeslegend, [l.get_label() for l in axeslegend])
# #Plot the ones for subarray 2
# l1=axes[1,0].plot(stop_div_sub_1_2_full, FoV_array_2[:array_slice_stop_sub_1_2_full], label='FoV',marker='o', color='darkgreen')
# ax5=axes[1,0].twinx()
# l2=ax5.plot(stop_div_sub_1_2_full, multiplicity_array_2[:array_slice_stop_sub_1_2_full], label='Multiplicity', marker='*', color='limegreen')
# axes[1,0].set_title('SUBARRAY 2')
# axes[1,0].set_xlabel('Divergence')
# axes[1,0].set_ylabel('Field of view[deg$^2$]')
# ax5.set_ylabel('Multiplicities')
# axeslegend = l1+l2
# axes[1,0].legend(axeslegend, [l.get_label() for l in axeslegend])
#
# # Subarray 3
# l1=axes[1,1].plot(stop_div, FoV_array_3[:array_slice_stop], label='FoV',marker='o', color='darkgreen')
# ax3 = axes[1,1].twinx()
# l2=ax3.plot(stop_div,multiplicity_array_3[:array_slice_stop], label='Multiplicities', marker='*', color='limegreen')
# plt.title('Subarray 3')
# plt.xlabel('Divergence')
# plt.ylabel('Field of view  [deg$^2$]')
# plt.ylabel('Multiplicities')
# axeslegend = l1+l2
# axes[1,1].legend(axeslegend, [l.get_label() for l in axeslegend])
# # Adjust layout
# plt.tight_layout()
# # Subarray 4
# l1=axes[2,1].plot(stop_div, FoV_array_4[:array_slice_stop], label='FoV',marker='o', color='darkgreen')
# ax3 = axes[2,1].twinx()
# l2=ax3.plot(stop_div,multiplicity_array_4[:array_slice_stop], label='Multiplicities', marker='*', color='limegreen')
# plt.title('Subarray 4')
# plt.xlabel('Divergence')
# plt.ylabel('Field of view  [deg$^2$]')
# plt.ylabel('Multiplicities')
# axeslegend = l1+l2
# axes[2,1].legend(axeslegend, [l.get_label() for l in axeslegend])
# # Adjust layout
# plt.tight_layout()
#
#
# plt.show()

# %% [markdown]
# # How it changes with zenith

# %%
#If you do not do this like this but just put array_alt_1=array and array_alt_2=array you will end up with a problem
#You will end up having them over write each pther because they come from the same point
array_alt_1= LoadConfig("./subarray_1_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_1_div_2= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_1_div_3= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)
array_alt_2= LoadConfig("./subarray_1_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_2_div_2= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_2_div_3= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)

array_alt_3= LoadConfig("./subarray_1_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_3_div_2= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)
#array_alt_3_div_3= LoadConfig("./subarray_1_SOUTH.txt", frame=cta, pointing2src=True)

array_2_alt_1= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_1_div_2= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_1_div_3= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)

array_2_alt_2= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_2_div_2= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_2_div_3= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
array_2_alt_3= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_3_div_2= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)
#array_2_alt_3_div_3= LoadConfig("./subarray_2_SOUTH.txt", frame=cta, pointing2src=True)

# %%
altitude_array=[70,50,30]
az=0

# %%
hFoV_altitude_1_configuration_1=[]
hFoV_altitude_2_configuration_1=[]
hFoV_altitude_3_configuration_1=[]
multiplicity_altitude_1_configuration_1=[]
multiplicity_altitude_2_configuration_1=[]
multiplicity_altitude_3_configuration_1=[]
for divergence in div_no_saturation_sub_1:
    for alt in altitude_array:
        array.divergent_pointing(div=divergence, az=0, alt=alt)
        print(f"The FoV and the average multiplicity is for array_1 with divergence{divergence:.2f} and altitude{alt:.2f} :",array.hFoV(subarray_mult=number_of_telescopes_subarray_1))
        if alt==altitude_array[0]:
            hFoV_altitude_1_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[0])
            multiplicity_altitude_1_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[1])
        if alt==altitude_array[1]:
            hFoV_altitude_2_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[0])
            multiplicity_altitude_2_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[1])
        if alt==altitude_array[2]:
            hFoV_altitude_3_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[0])
            multiplicity_altitude_3_configuration_1.append(array.hFoV(subarray_mult=number_of_telescopes_subarray_1)[1])
        array.multiplicity_plot(number_of_telescopes_subarray_1)
# Out:
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude70.00 : (51.32805198994542, 12.70056208482371)
# 4it [00:00,  7.30it/s]
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.40it/s]
# 4it [00:00,  6.99it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.27it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude50.00 : (50.64612590321135, 12.860693940963232)
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.53it/s]
# 4it [00:00,  6.89it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.29it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude30.00 : (49.924857926857996, 13.045967953769372)
# 4it [00:00,  7.51it/s]
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.57it/s]
# 4it [00:00,  7.02it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.26it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude70.00 : (56.06219270746465, 11.630175438596492)
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.45it/s]
# 4it [00:00,  6.96it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.58it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude50.00 : (54.84259412926718, 11.876374940219991)
# 4it [00:00,  7.51it/s]
# 4it [00:00,  7.39it/s]
# 4it [00:00,  7.44it/s]
# 4it [00:00,  6.94it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.45it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.00 and altitude30.00 : (53.33448836052836, 12.219818047701008)
# 4it [00:00,  7.21it/s]
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.04it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude70.00 : (64.5469269020213, 10.083299471759448)
# 4it [00:00,  7.28it/s]
# 4it [00:00,  7.55it/s]
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.00it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.45it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude50.00 : (62.737199979534715, 10.382734113712374)
# 4it [00:00,  7.38it/s]
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.49it/s]
# 4it [00:00,  6.80it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.52it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude30.00 : (59.36691143548362, 10.968190854870775)
# 4it [00:00,  7.21it/s]
# 4it [00:00,  7.60it/s]
# 4it [00:00,  7.44it/s]
# 4it [00:00,  7.09it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.52it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude70.00 : (72.86117957489442, 8.943664506839452)
# 4it [00:00,  7.52it/s]
# 4it [00:00,  7.21it/s]
# 4it [00:00,  7.34it/s]
# 4it [00:00,  6.83it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.31it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude50.00 : (69.84496803741679, 9.335711603454751)
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.47it/s]
# 4it [00:00,  6.80it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude30.00 : (65.11082731989755, 10.004229607250755)
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.18it/s]
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.11it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.18it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude70.00 : (80.87381109401977, 8.061942597697422)
# 4it [00:00,  7.47it/s]
# 4it [00:00,  7.29it/s]
# 4it [00:00,  7.44it/s]
# 4it [00:00,  6.99it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.48it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude50.00 : (76.72979872078963, 8.481627072295334)
# 4it [00:00,  7.47it/s]
# 4it [00:00,  7.52it/s]
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.10it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.43it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.01 and altitude30.00 : (70.7104896090408, 9.21902818991098)
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.38it/s]
# 4it [00:00,  7.51it/s]
# 4it [00:00,  7.10it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.53it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude70.00 : (88.5979354226038, 7.35287152161042)
# 4it [00:00,  7.29it/s]
# 4it [00:00,  7.56it/s]
# 4it [00:00,  7.12it/s]
# 4it [00:00,  6.97it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.54it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude50.00 : (83.75888299943315, 7.777516831063097)
# 4it [00:00,  7.57it/s]
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.06it/s]
# 4it [00:00,  6.77it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  6.87it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude30.00 : (76.15278433970695, 8.559152746685035)
# 4it [00:00,  7.44it/s]
# 4it [00:00,  7.10it/s]
# 4it [00:00,  7.36it/s]
# 4it [00:00,  6.91it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.48it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude70.00 : (96.54499712569702, 6.748709589785385)
# 4it [00:00,  7.38it/s]
# 4it [00:00,  7.27it/s]
# 4it [00:00,  7.33it/s]
# 4it [00:00,  6.90it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.44it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude50.00 : (90.91910691014093, 7.16962353959325)
# 4it [00:00,  7.44it/s]
# 4it [00:00,  7.53it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.02it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.47it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude30.00 : (81.80490248167591, 7.972747675537031)
# 4it [00:00,  7.36it/s]
# 4it [00:00,  7.45it/s]
# 4it [00:00,  7.47it/s]
# 4it [00:00,  6.94it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.34it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude70.00 : (104.79367998253802, 6.222250031285196)
# 4it [00:00,  7.57it/s]
# 4it [00:00,  7.47it/s]
# 4it [00:00,  7.53it/s]
# 4it [00:00,  6.12it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.43it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude50.00 : (98.1317866736744, 6.641988507283175)
# 4it [00:00,  7.45it/s]
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.31it/s]
# 4it [00:00,  6.41it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.02 and altitude30.00 : (87.40456477081916, 7.456114028507127)
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.38it/s]
# 4it [00:00,  7.36it/s]
# 4it [00:00,  6.99it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.03 and altitude70.00 : (112.95056509693406, 5.765586903517938)
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.36it/s]
# 4it [00:00,  7.45it/s]
# 4it [00:00,  6.64it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.29it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.03 and altitude50.00 : (105.50183399568495, 6.174766935985084)
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.08it/s]
# The barycenter -26.08250000000001
# The barycenter -13.394999999999996
# The barycenter 28.009999999999998
# 4it [00:00,  7.54it/s]
# The FoV and the average multiplicity is for array_1 with divergence0.03 and altitude30.00 : (93.03045498637526, 6.995630109952073)
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.41it/s]
# 4it [00:00,  6.95it/s]

# %%
hFoV_altitude_1_configuration_2=[]
hFoV_altitude_2_configuration_2=[]
hFoV_altitude_3_configuration_2=[]
multiplicity_altitude_1_configuration_2=[]
multiplicity_altitude_2_configuration_2=[]
multiplicity_altitude_3_configuration_2=[]
for divergence in div_no_saturation_sub_2:
    for alt in altitude_array:
        array_2.divergent_pointing(div=divergence, az=0, alt=alt)
        print(f"The FoV and the average multiplicity is for array_2 with divergence{divergence:.2f} and altitude{alt:.2f} :",array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2))
        if alt==altitude_array[0]:
            hFoV_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[0])
            multiplicity_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
        if alt==altitude_array[1]:
            hFoV_altitude_2_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[0])
            multiplicity_altitude_2_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
        if alt==altitude_array[2]:
            hFoV_altitude_3_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[0])
            multiplicity_altitude_3_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
        array_2.multiplicity_plot(number_of_telescopes_subarray_2)
# Out:
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.40it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude70.00 : (51.31493802673899, 12.68285203168924)
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.51it/s]
# 4it [00:00,  6.80it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.45it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude50.00 : (50.908405167339836, 12.802163833075735)
# 4it [00:00,  7.53it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.26it/s]
# 4it [00:00,  6.89it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.28it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude30.00 : (50.01665566930297, 13.02464604090194)
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.56it/s]
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.16it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude70.00 : (56.285130081973875, 11.572227399813606)
# 4it [00:00,  7.44it/s]
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.51it/s]
# 4it [00:00,  6.78it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude50.00 : (55.22289906225349, 11.807646639753028)
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.37it/s]
# 4it [00:00,  6.81it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.52it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.00 and altitude30.00 : (53.570539698244005, 12.161321909424725)
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.22it/s]
# 4it [00:00,  7.14it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.36it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude70.00 : (65.42556243685173, 9.980156343956704)
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.05it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.44it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude50.00 : (63.02570717007605, 10.337702871410736)
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.42it/s]
# 4it [00:00,  6.87it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude30.00 : (59.81278618450206, 10.891690418767814)
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.42it/s]
# 4it [00:00,  7.26it/s]
# 4it [00:00,  7.04it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.40it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude70.00 : (73.70047322010558, 8.845729537366548)
# 4it [00:00,  7.45it/s]
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.32it/s]
# 4it [00:00,  6.93it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.49it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude50.00 : (70.52689412415086, 9.24246931944961)
# 4it [00:00,  7.25it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  6.78it/s]
# 4it [00:00,  6.62it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  6.61it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude30.00 : (65.76652548021877, 9.914257228315055)
# 4it [00:00,  6.81it/s]
# 4it [00:00,  6.78it/s]
# 4it [00:00,  7.37it/s]
# 4it [00:00,  6.42it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  6.80it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude70.00 : (81.97538400335944, 7.9504079347304435)
# 4it [00:00,  7.03it/s]
# 4it [00:00,  6.83it/s]
# 4it [00:00,  6.92it/s]
# 4it [00:00,  6.50it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  6.90it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude50.00 : (77.7264599244779, 8.38704234857432)
# 4it [00:00,  6.62it/s]
# 4it [00:00,  7.09it/s]
# 4it [00:00,  6.62it/s]
# 4it [00:00,  6.86it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  6.86it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.01 and altitude30.00 : (71.5628972174584, 9.103353490929083)
# 4it [00:00,  6.90it/s]
# 4it [00:00,  6.99it/s]
# 4it [00:00,  7.15it/s]
# 4it [00:00,  6.94it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.20it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude70.00 : (89.89621778003982, 7.248869438366156)
# 4it [00:00,  7.39it/s]
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.36it/s]
# 4it [00:00,  6.93it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.52it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude50.00 : (85.07027932007561, 7.662710035455526)
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.24it/s]
# 4it [00:00,  7.24it/s]
# 4it [00:00,  6.99it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude30.00 : (77.04453383774383, 8.45276595744681)
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.33it/s]
# 4it [00:00,  6.94it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.55it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude70.00 : (98.22358441611937, 6.6395193591455275)
# 4it [00:00,  7.55it/s]
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.05it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.51it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude50.00 : (92.33541493643477, 7.06064479477347)
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.45it/s]
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.05it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.23it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude30.00 : (82.84090557498345, 7.867817001741333)
# 4it [00:00,  7.23it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.44it/s]
# 4it [00:00,  6.96it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.31it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude70.00 : (106.55095105219891, 6.116307692307692)
# 4it [00:00,  7.55it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.51it/s]
# 4it [00:00,  6.92it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude50.00 : (99.81037396409673, 6.530679279989489)
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.10it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.38it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.02 and altitude30.00 : (88.83398676031943, 7.336433421907293)
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.41it/s]
# 4it [00:00,  6.78it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.54it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude70.00 : (115.10125506278767, 5.663210664236072)
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.35it/s]
# 4it [00:00,  7.01it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.36it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude50.00 : (107.4033586606165, 6.0737484737484735)
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.37it/s]
# 4it [00:00,  7.19it/s]
# 4it [00:00,  6.46it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.34it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude30.00 : (94.95820757771966, 6.868940754039497)
# 4it [00:00,  7.47it/s]
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.20it/s]
# 4it [00:00,  6.99it/s]

# %% [markdown]
# pointings90=[]
# pointings70=[]
# pointings50=[]
# pointings30=[]
# pointings0=[]
# for alt in altitude_array:
#         array.divergent_pointing(div=0.03, az=0, alt=alt)
#         coord=array.get_pointing_coord(icrs=False)
#         for i, tel in tqdm.tqdm(enumerate(array.telescopes)):
#             if alt ==90:
#                 pointings90.append(SkyCoord(ra=coord.az[i].degree, dec=coord.alt[i].degree, unit='deg'))
#             elif alt ==70:
#                 pointings70.append(SkyCoord(ra=coord.az[i].degree, dec=coord.alt[i].degree, unit='deg'))
#             elif alt ==50:
#                 pointings50.append(SkyCoord(ra=coord.az[i].degree, dec=coord.alt[i].degree, unit='deg'))
#             elif alt ==30:
#                 pointings30.append(SkyCoord(ra=coord.az[i].degree, dec=coord.alt[i].degree, unit='deg'))
#             elif alt ==0:
#                 pointings0.append(SkyCoord(ra=coord.az[i].degree, dec=coord.alt[i].degree, unit='deg'))
#
# print(90, pointings90)
# print(70, pointings70)
# print(50, pointings50)
# print(30, pointings30)
# print(0, pointings0)

# %% [markdown]
# def SepAng(coords):
#     normcoords=[]
#     for i in range(len(coords)):
#         normcoords.append(SkyCoord(ra=0, dec=coords[i].dec, unit='deg'))
#     separations=[]
#     for i in range(len(normcoords)):
#         for t in range(len(normcoords)):
#             if t>i:
#                 separations.append(normcoords[i].separation(normcoords[t]))
#     return separations
# #separations=[]
# #print(SepAng(pointings90))
# print(SepAng(pointings70))
# print(SepAng(pointings50))
# print(SepAng(pointings30))
# print(SepAng(pointings0))

# %% [markdown]
# pointingsRD=[]
# for alt in altitude_array:
#         pointingsRD.append('Altitude: {}'.format(alt))
#         array.divergent_pointing(div=0.03, az=0, alt=alt)
#         coord=array.get_pointing_coord(icrs=True)
#         for i, tel in tqdm.tqdm(enumerate(array.telescopes)):
#             #if alt ==altitude_array[0]:
#             pointingsRD.append(SkyCoord(ra=coord.ra[i].degree, dec=coord.dec[i].degree, unit='deg'))
#
# print(pointingsRD)

# %%
#HfOv VS THE ALTITUDE WITH THE SAME DIVERGENCE 0.0304

# %%
hFoV_altitude_1_configuration_2
# Out:
# [51.31493802673899,
#  56.285130081973875,
#  65.42556243685173,
#  73.70047322010558,
#  81.97538400335944,
#  89.89621778003982,
#  98.22358441611937,
#  106.55095105219891,
#  115.10125506278767]

# %%
plt.scatter(hFoV_altitude_1_configuration_2,div_no_saturation_sub_2, label=f'Altitude {altitude_array[0]}')
plt.scatter(hFoV_altitude_2_configuration_2,div_no_saturation_sub_2, label=f'Altitude {altitude_array[1]}')
plt.scatter(hFoV_altitude_3_configuration_2,div_no_saturation_sub_2, label=f'Altitude {altitude_array[2]}')
plt.ylabel("Divergence")  
plt.xlabel("FoV") 
plt.title("FoV vs Divergence different altitudes configuration 2")  # Title of the plot
plt.legend()
plt.show()

# %%
plt.scatter(hFoV_altitude_3_configuration_1,div_no_saturation_sub_1, label=f'config 1 ALTITUDE: {altitude_array[2]}', color='darkseagreen')
plt.scatter(hFoV_altitude_3_configuration_2,div_no_saturation_sub_1, label=f'config 3 ALTITUDE: {altitude_array[2]}', color='mediumorchid')
plt.scatter(hFoV_altitude_2_configuration_1,div_no_saturation_sub_1, label=f'config 1 ALTITUDE: {altitude_array[1]}', color='limegreen')
plt.scatter(hFoV_altitude_2_configuration_2,div_no_saturation_sub_1, label=f'config 3 ALTITUDE: {altitude_array[1]}', color='mediumpurple')
plt.scatter(hFoV_altitude_1_configuration_1,div_no_saturation_sub_1, label=f'config 1 ALTITUDE: {altitude_array[0]}', color='seagreen')
plt.scatter(hFoV_altitude_1_configuration_2,div_no_saturation_sub_1, label=f'config 3 ALTITUDE:{altitude_array[0]}', color='darkmagenta')
plt.ylabel("Divergence")  
plt.xlabel("hFoV[$deg^2$]") 
plt.title("hFoV vs Divergence different altitudes config 1 and config 3")  # Title of the plot
plt.legend()
plt.show()

# %%
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_3_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[2]}', color='darkseagreen')
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_3_configuration_2, label=f'config 3 ALTITUDE: {altitude_array[2]}', color='mediumorchid')
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_2_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[1]}', color='limegreen')
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_2_configuration_2, label=f'config 3 ALTITUDE: {altitude_array[1]}', color='mediumpurple')
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_1_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[0]}', color='seagreen')
plt.scatter(div_no_saturation_sub_1,hFoV_altitude_1_configuration_2, label=f'config 3 ALTITUDE:{altitude_array[0]}', color='darkmagenta')
plt.ylabel("hFoV[$deg^2$]")  
plt.xlabel("Divergence") 
plt.title("hFoV vs Divergence different altitudes config 1 and config 3")  # Title of the plot
plt.legend()
plt.show()

# %%
plt.scatter(div_no_saturation_sub_1,multiplicity_altitude_3_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[2]}', color='darkseagreen')
plt.scatter(div_no_saturation_sub_1,multiplicity_altitude_3_configuration_2, label=f'config 3 ALTITUDE: {altitude_array[2]}', color='mediumorchid')
plt.scatter(div_no_saturation_sub_1,multiplicity_altitude_2_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[1]}', color='limegreen')
plt.scatter(div_no_saturation_sub_1, multiplicity_altitude_2_configuration_2,label=f'config 3 ALTITUDE: {altitude_array[1]}', color='mediumpurple')
plt.scatter(div_no_saturation_sub_1,multiplicity_altitude_1_configuration_1, label=f'config 1 ALTITUDE: {altitude_array[0]}', color='seagreen')
plt.scatter(div_no_saturation_sub_1,multiplicity_altitude_1_configuration_2, label=f'config 3 ALTITUDE:{altitude_array[0]}', color='darkmagenta')
plt.ylabel("Multilpicity")  
plt.xlabel("Divergence") 
plt.title(" Divergence vs Multiplicity different altitudes config 1 and config 3")  # Title of the plot
plt.legend()
plt.show()

# %%
#Do the same graphs again to show what happens for different altitudes 
#maybe try as well the different arrays between how many are for the same

# %%
hFoV_altitude_1_configuration_2=[]
hFoV_altitude_2_configuration_2=[]
hFoV_altitude_3_configuration_2=[]
multiplicity_altitude_1_configuration_2=[]
multiplicity_altitude_2_configuration_2=[]
multiplicity_altitude_3_configuration_2=[]
for alt in altitude_array:
    array_2.divergent_pointing(div=0.03, az=0, alt=alt)
    print(f"The FoV and the average multiplicity is for array_2 with divergence{divergence:.2f} and altitude{alt:.2f} :",array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2, m_cut=12))
    if alt==altitude_array[0]:
        hFoV_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2, m_cut=12)[0])
        multiplicity_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
    if alt==altitude_array[1]:
        hFoV_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2,  m_cut=12)[0])
        multiplicity_altitude_2_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
    if alt==altitude_array[2]:
        hFoV_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2,  m_cut=12)[0])
        multiplicity_altitude_3_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2)[1])
    array_2.multiplicity_plot(number_of_telescopes_subarray_2)
# Out:
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.36it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude70.00 : (1.665473327215909, 14.0)
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.51it/s]
# 4it [00:00,  7.32it/s]
# 4it [00:00,  6.90it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.37it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude50.00 : (4.406291637358626, 14.0)
# 4it [00:00,  7.25it/s]
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.49it/s]
# 4it [00:00,  6.88it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.49it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude30.00 : (9.520737287864174, 14.0)
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.36it/s]
# 4it [00:00,  6.99it/s]

# %%
plt.scatter(hFoV_altitude_1_configuration_2,altitude_array)
plt.show()

# %%
altitude_array=[0,15,45,60,75,90]

# %%
hFoV_altitude_mult_1=[]
hFoV_altitude_1_configuration_2=[]
hFoV_altitude_3_configuration_2=[]
multiplicity_altitude_1_configuration_2=[]
multiplicity_altitude_2_configuration_2=[]
multiplicity_altitude_3_configuration_2=[]
multiplicities=[1,2,3,6,7,8,9,10,11,12]
for m_cut in multiplicities:
    hFoV_altitude_mult_1=[]
    hFoV_altitude_1_configuration_2=[]
    hFoV_altitude_3_configuration_2=[]
    multiplicity_altitude_1_configuration_2=[]
    multiplicity_altitude_2_configuration_2=[]
    multiplicity_altitude_3_configuration_2=[]
    for alt in altitude_array:
        array_2.divergent_pointing(div=0.03, az=0, alt=alt)
        print(f"The FoV and the average multiplicity is for array_2 with divergence{divergence:.2f} and altitude{alt:.2f} :",array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2, m_cut=m_cut))
        hFoV_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2, m_cut=m_cut)[0])
        multiplicity_altitude_1_configuration_2.append(array_2.hFoV(subarray_mult=number_of_telescopes_subarray_2, m_cut=m_cut)[1])
   # plt.scatter(hFoV_altitude_1_configuration_2,altitude_array, label="hFoV")
    plt.scatter(altitude_array,multiplicity_altitude_1_configuration_2, label="Multiplicity")
    plt.title(f"The m_cut is {m_cut}")
    plt.xlabel("Altitude")
    plt.ylabel("Multiplicity/hFoV")
    plt.legend()
    plt.show()
# Out:
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.37it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (76.48063341986757, 8.527091906721536)
# 4it [00:00,  7.39it/s]
# 4it [00:00,  7.33it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (88.40122597450743, 7.366859516392227)
# 4it [00:00,  7.28it/s]
# 4it [00:00,  7.38it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.36it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (113.0817047289983, 5.756001391627044)
# 4it [00:00,  7.20it/s]
# 4it [00:00,  7.33it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.35it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (121.50086910752282, 5.365569347004857)
# 4it [00:01,  3.78it/s]
# 4it [00:00,  4.64it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  6.81it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (126.03830037694568, 5.171990427635001)
# 4it [00:00,  7.22it/s]
# 4it [00:00,  7.29it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.00it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (127.50706425606523, 5.115087935822277)
# 4it [00:00,  7.48it/s]
# 4it [00:01,  3.96it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.34it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (76.48063341986757, 8.527091906721536)
# 4it [00:00,  7.26it/s]
# 4it [00:00,  7.48it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.50it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (88.40122597450743, 7.366859516392227)
# 4it [00:00,  7.27it/s]
# 4it [00:00,  7.28it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (113.0817047289983, 5.756001391627044)
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.41it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  4.26it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (121.50086910752282, 5.365569347004857)
# 4it [00:00,  7.02it/s]
# 4it [00:00,  7.42it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.33it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (126.03830037694568, 5.171990427635001)
# 4it [00:00,  7.37it/s]
# 4it [00:00,  7.24it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.60it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (127.50706425606523, 5.115087935822277)
# 4it [00:00,  7.60it/s]
# 4it [00:00,  7.22it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.44it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (66.1599443764115, 9.389296333002973)
# 4it [00:00,  6.24it/s]
# 4it [00:00,  7.27it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (67.64182221873747, 8.707056998836759)
# 4it [00:00,  7.37it/s]
# 4it [00:00,  6.98it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.54it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (76.36260775100975, 7.081229606731925)
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.05it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.49it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (80.30991067614352, 6.578870019595036)
# 4it [00:00,  7.40it/s]
# 4it [00:00,  7.15it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.38it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (82.57862631085496, 6.315070668572336)
# 4it [00:00,  7.50it/s]
# 4it [00:00,  4.28it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.44it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (83.74576903622673, 6.220325712496085)
# 4it [00:00,  7.60it/s]
# 4it [00:00,  7.56it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.38it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (65.35999262081961, 9.455256821829856)
# 4it [00:00,  7.20it/s]
# 4it [00:00,  7.22it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.12it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (56.52118141968951, 9.58399071925754)
# 4it [00:00,  7.09it/s]
# 4it [00:00,  7.47it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:01,  3.95it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (43.21050876516866, 9.028831562974203)
# 4it [00:00,  7.43it/s]
# 4it [00:00,  7.44it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (39.171408097589925, 8.667894208235689)
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.38it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (36.86335057325922, 8.434009249377446)
# 4it [00:00,  7.53it/s]
# 4it [00:00,  7.45it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.45it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (35.97160107522235, 8.364199781261393)
# 4it [00:00,  4.35it/s]
# 4it [00:00,  7.58it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.29it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (27.027878168440854, 12.93740902474527)
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.45it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.50it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (28.535983937179672, 12.118106617647058)
# 4it [00:00,  7.37it/s]
# 4it [00:00,  7.42it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.38it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (29.17856813429447, 10.004494382022472)
# 4it [00:00,  7.53it/s]
# 4it [00:01,  3.95it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.25it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (28.404844305115425, 9.300092336103416)
# 4it [00:00,  7.44it/s]
# 4it [00:00,  7.28it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.51it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (27.906513703271294, 8.894266917293233)
# 4it [00:00,  7.46it/s]
# 4it [00:00,  7.25it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.70it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (27.499980843872137, 8.784453981878874)
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.48it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:01,  4.00it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (26.83116872034449, 12.973607038123166)
# 4it [00:00,  7.23it/s]
# 4it [00:00,  7.47it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.29it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (25.178809356335, 12.6671875)
# 4it [00:00,  7.50it/s]
# 4it [00:00,  7.57it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.14it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (15.212197319452399, 11.844827586206897)
# 4it [00:00,  7.53it/s]
# 4it [00:00,  7.14it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.32it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (10.727221902855225, 11.442542787286063)
# 4it [00:00,  4.03it/s]
# 4it [00:00,  7.35it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.44it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (8.156885114396028, 11.059485530546624)
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.41it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.54it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (7.4487311012491055, 10.89612676056338)
# 4it [00:00,  7.63it/s]
# 4it [00:00,  7.55it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.37it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (26.83116872034449, 12.973607038123166)
# 4it [00:00,  6.95it/s]
# 4it [00:00,  4.11it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.36it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (25.178809356335, 12.6671875)
# 4it [00:00,  7.60it/s]
# 4it [00:00,  7.55it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.42it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (15.212197319452399, 11.844827586206897)
# 4it [00:00,  7.45it/s]
# 4it [00:00,  7.24it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.37it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (10.727221902855225, 11.442542787286063)
# 4it [00:00,  7.32it/s]
# 4it [00:00,  7.60it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.53it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (8.156885114396028, 11.059485530546624)
# 4it [00:00,  7.31it/s]
# 4it [00:00,  7.61it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.25it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (7.4487311012491055, 10.89612676056338)
# 4it [00:00,  7.52it/s]
# 4it [00:00,  7.71it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.56it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (26.83116872034449, 12.973607038123166)
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.54it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.51it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (23.44776621308697, 12.864093959731544)
# 4it [00:00,  7.61it/s]
# 4it [00:00,  7.50it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.09it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (11.697655180130637, 12.399103139013453)
# 4it [00:00,  7.45it/s]
# 4it [00:01,  3.87it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.48it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (7.252021653152738, 12.13381555153707)
# 4it [00:00,  7.33it/s]
# 4it [00:00,  7.52it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.55it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (4.668570901487115, 11.851123595505618)
# 4it [00:00,  7.36it/s]
# 4it [00:00,  7.13it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.50it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (3.842391219482373, 11.737201365187714)
# 4it [00:00,  7.49it/s]
# 4it [00:00,  7.53it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:01,  3.88it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (17.65139447584735, 14.0)
# 4it [00:00,  7.31it/s]
# 4it [00:00,  7.61it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (14.569613122337598, 14.0)
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.22it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.41it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (5.4554086938725845, 14.0)
# 4it [00:00,  7.54it/s]
# 4it [00:00,  7.48it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.59it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (2.7408183101427164, 14.0)
# 4it [00:00,  7.56it/s]
# 4it [00:00,  7.49it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  4.29it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (1.3245102838488725, 14.0)
# 4it [00:00,  7.58it/s]
# 4it [00:00,  7.44it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.33it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (0.9442053508625626, 14.0)
# 4it [00:00,  7.63it/s]
# 4it [00:00,  7.60it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.26it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude0.00 : (17.65139447584735, 14.0)
# 4it [00:00,  7.27it/s]
# 4it [00:00,  7.42it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.58it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude15.00 : (14.569613122337598, 14.0)
# 4it [00:00,  4.11it/s]
# 4it [00:00,  7.33it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.51it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude45.00 : (5.4554086938725845, 14.0)
# 4it [00:00,  7.25it/s]
# 4it [00:00,  7.54it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.39it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude60.00 : (2.7408183101427164, 14.0)
# 4it [00:00,  7.34it/s]
# 4it [00:00,  7.51it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.48it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude75.00 : (1.3245102838488725, 14.0)
# 4it [00:00,  7.48it/s]
# 4it [00:00,  7.50it/s]
# The barycenter -45.102500000000006
# The barycenter 0.0
# The barycenter 28.0825
# 4it [00:00,  7.50it/s]
# The FoV and the average multiplicity is for array_2 with divergence0.03 and altitude90.00 : (0.9442053508625626, 14.0)
# 4it [00:00,  7.41it/s]
# 4it [00:00,  7.47it/s]

# %%
hFoV_altitude_1_configuration_2
# Out:
# [17.65139447584735,
#  14.569613122337598,
#  5.4554086938725845,
#  2.7408183101427164,
#  1.3245102838488725,
#  0.9442053508625626]

# %%
altitude_array
# Out:
# [0, 15, 45, 60, 75, 90]

# %%
altitude_array
# Out:
# [0, 15, 45, 60, 75, 90]
